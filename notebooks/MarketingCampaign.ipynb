# %% [markdown]
# # Importing Datasets and Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
market_df=pd.read_csv("market_train.csv",sep=";")

# %%
market_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
market_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
market_df["marital"].value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
market_df["marital"]=market_df["marital"].map({"married":0,"single":1,"divorced":2})

# %%
market_df["education"].value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
market_df["contact"].value_counts()
# Out:
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %%
market_df["contact"]=market_df["contact"].map({"cellular":0,"unknown":1,"telephone":2})

# %%
market_df=market_df.drop("poutcome",axis=1)

# %%
market_df["default"]=market_df["default"].map({"no":0,"yes":1})
market_df["loan"]=market_df["loan"].map({"no":0,"yes":1})
market_df["y"]=market_df["y"].map({"no":0,"yes":1})

# %%
market_df["education"]=market_df["education"].map({"unknown":0,"primary":1,"secondary":2,"tertiary":3})

# %%
market_df.head()
# Out:
#    age           job  marital  education  default  balance housing  loan  \
# 0   58    management        0          3        0     2143     yes     0
# 1   44    technician        1          2        0       29     yes     0
# 2   33  entrepreneur        0          2        0        2     yes     1
# 3   47   blue-collar        0          0        0     1506     yes     0
# 4   33       unknown        1          0        0        1      no     0
#
#    contact  day month  duration  campaign  pdays  previous  y
# 0        1    5   may       261         1     -1         0  0
# 1        1    5   may       151         1     -1         0  0
# 2        1    5   may        76         1     -1         0  0
# 3        1    5   may        92         1     -1         0  0
# 4        1    5   may       198         1     -1         0  0

# %%
market_df=market_df.drop(["balance"],axis=1)

# %%
market_df.head()
# Out:
#    age           job  marital  education  default housing  loan  contact  day  \
# 0   58    management        0          3        0     yes     0        1    5
# 1   44    technician        1          2        0     yes     0        1    5
# 2   33  entrepreneur        0          2        0     yes     1        1    5
# 3   47   blue-collar        0          0        0     yes     0        1    5
# 4   33       unknown        1          0        0      no     0        1    5
#
#   month  duration  campaign  pdays  previous  y
# 0   may       261         1     -1         0  0
# 1   may       151         1     -1         0  0
# 2   may        76         1     -1         0  0
# 3   may        92         1     -1         0  0
# 4   may       198         1     -1         0  0

# %%
market_df["housing"]=market_df["housing"].map({"yes":1,"no":0})

# %%
market_df["job"].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
market_df["month"].value_counts()
# Out:
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64

# %%
market_df["month"]=market_df["month"].map({"jan":0,"feb":1,"mar":2,"apr":3,"may":4,"jun":5,"july":6,"august":7,"sep":8,"oct":9,"nov":10,"dec":11})

# %%
market_df.head()
# Out:
#    age           job  marital  education  default  housing  loan  contact  \
# 0   58    management        0          3        0        1     0        1
# 1   44    technician        1          2        0        1     0        1
# 2   33  entrepreneur        0          2        0        1     1        1
# 3   47   blue-collar        0          0        0        1     0        1
# 4   33       unknown        1          0        0        0     0        1
#
#    day  month  duration  campaign  pdays  previous  y
# 0    5    4.0       261         1     -1         0  0
# 1    5    4.0       151         1     -1         0  0
# 2    5    4.0        76         1     -1         0  0
# 3    5    4.0        92         1     -1         0  0
# 4    5    4.0       198         1     -1         0  0

# %%
market_df[market_df["y"]==0]
# Out:
#        age           job  marital  education  default  housing  loan  contact  \
# 0       58    management        0          3        0        1     0        1
# 1       44    technician        1          2        0        1     0        1
# 2       33  entrepreneur        0          2        0        1     1        1
# 3       47   blue-collar        0          0        0        1     0        1
# 4       33       unknown        1          0        0        0     0        1
# ...    ...           ...      ...        ...      ...      ...   ...      ...
# 45194   59    management        0          3        0        1     1        0
# 45198   37    management        0          3        0        0     0        0
# 45199   34   blue-collar        1          2        0        1     0        0
# 45209   57   blue-collar        0          2        0        0     0        2
# 45210   37  entrepreneur        0          2        0        0     0        0
#
#        day  month  duration  campaign  pdays  previous  y
# 0        5    4.0       261         1     -1         0  0
# 1        5    4.0       151         1     -1         0  0
# 2        5    4.0        76         1     -1         0  0
# 3        5    4.0        92         1     -1         0  0
# 4        5    4.0       198         1     -1         0  0
# ...    ...    ...       ...       ...    ...       ... ..
# 45194   16   10.0       162         2    187         5  0
# 45198   16   10.0       333         2     -1         0  0
# 45199   16   10.0      1166         3    530        12  0
# 45209   17   10.0       508         4     -1         0  0
# 45210   17   10.0       361         2    188        11  0
#
# [39922 rows x 15 columns]

# %%
market_df.dropna()
# Out:
#        age           job  marital  education  default  housing  loan  contact  \
# 0       58    management        0          3        0        1     0        1
# 1       44    technician        1          2        0        1     0        1
# 2       33  entrepreneur        0          2        0        1     1        1
# 3       47   blue-collar        0          0        0        1     0        1
# 4       33       unknown        1          0        0        0     0        1
# ...    ...           ...      ...        ...      ...      ...   ...      ...
# 45206   51    technician        0          3        0        0     0        0
# 45207   71       retired        2          1        0        0     0        0
# 45208   72       retired        0          2        0        0     0        0
# 45209   57   blue-collar        0          2        0        0     0        2
# 45210   37  entrepreneur        0          2        0        0     0        0
#
#        day  month  duration  campaign  pdays  previous  y
# 0        5    4.0       261         1     -1         0  0
# 1        5    4.0       151         1     -1         0  0
# 2        5    4.0        76         1     -1         0  0
# 3        5    4.0        92         1     -1         0  0
# 4        5    4.0       198         1     -1         0  0
# ...    ...    ...       ...       ...    ...       ... ..
# 45206   17   10.0       977         3     -1         0  1
# 45207   17   10.0       456         2     -1         0  1
# 45208   17   10.0      1127         5    184         3  1
# 45209   17   10.0       508         4     -1         0  0
# 45210   17   10.0       361         2    188        11  0
#
# [32069 rows x 15 columns]

# %%
market_df.isnull().sum()
# Out:
# age              0
# job              0
# marital          0
# education        0
# default          0
# housing          0
# loan             0
# contact          0
# day              0
# month        13142
# duration         0
# campaign         0
# pdays            0
# previous         0
# y                0
# dtype: int64

# %%
market_df["job"]=market_df["job"].map({"unknown":0,"unemployed":1,"student":2,"housemaid":3,"blue-collar":4,"technician":5,"services":6,"retired":7,"self-employed":8,"entrepreneur":9,"admin":10,"management":11})

# %%
market_df.head(50)
# Out:
#     age   job  marital  education  default  housing  loan  contact  day  \
# 0    58  11.0        0          3        0        1     0        1    5
# 1    44   5.0        1          2        0        1     0        1    5
# 2    33   9.0        0          2        0        1     1        1    5
# 3    47   4.0        0          0        0        1     0        1    5
# 4    33   0.0        1          0        0        0     0        1    5
# 5    35  11.0        0          3        0        1     0        1    5
# 6    28  11.0        1          3        0        1     1        1    5
# 7    42   9.0        2          3        1        1     0        1    5
# 8    58   7.0        0          1        0        1     0        1    5
# 9    43   5.0        1          2        0        1     0        1    5
# 10   41   NaN        2          2        0        1     0        1    5
# 11   29   NaN        1          2        0        1     0        1    5
# 12   53   5.0        0          2        0        1     0        1    5
# 13   58   5.0        0          0        0        1     0        1    5
# 14   57   6.0        0          2        0        1     0        1    5
# 15   51   7.0        0          1        0        1     0        1    5
# 16   45   NaN        1          0        0        1     0        1    5
# 17   57   4.0        0          1        0        1     0        1    5
# 18   60   7.0        0          1        0        1     0        1    5
# 19   33   6.0        0          2        0        1     0        1    5
# 20   28   4.0        0          2        0        1     1        1    5
# 21   56  11.0        0          3        0        1     0        1    5
# 22   32   4.0        1          1        0        1     1        1    5
# 23   25   6.0        0          2        0        1     0        1    5
# 24   40   7.0        0          1        0        1     1        1    5
# 25   44   NaN        0          2        0        1     0        1    5
# 26   39  11.0        1          3        0        1     0        1    5
# 27   52   9.0        0          2        0        1     1        1    5
# 28   46  11.0        1          2        0        1     0        1    5
# 29   36   5.0        1          2        0        1     1        1    5
# 30   57   5.0        0          2        0        0     1        1    5
# 31   49  11.0        0          3        0        1     0        1    5
# 32   60   NaN        0          2        0        1     1        1    5
# 33   59   4.0        0          2        0        1     0        1    5
# 34   51  11.0        0          3        0        1     0        1    5
# 35   57   5.0        2          2        0        1     0        1    5
# 36   25   4.0        0          2        0        1     0        1    5
# 37   53   5.0        0          2        0        0     0        1    5
# 38   36   NaN        2          2        0        1     0        1    5
# 39   37   NaN        1          2        0        1     0        1    5
# 40   44   6.0        2          2        0        1     0        1    5
# 41   50  11.0        0          2        0        1     0        1    5
# 42   60   4.0        0          0        0        1     0        1    5
# 43   54   7.0        0          2        0        1     0        1    5
# 44   58   7.0        0          0        0        1     0        1    5
# 45   36   NaN        1          1        0        1     0        1    5
# 46   58   8.0        0          3        0        1     0        1    5
# 47   44   5.0        0          2        0        1     0        1    5
# 48   55   5.0        2          2        0        0     0        1    5
# 49   29  11.0        1          3        0        1     0        1    5
#
#     month  duration  campaign  pdays  previous  y
# 0     4.0       261         1     -1         0  0
# 1     4.0       151         1     -1         0  0
# 2     4.0        76         1     -1         0  0
# 3     4.0        92         1     -1         0  0
# 4     4.0       198         1     -1         0  0
# 5     4.0       139         1     -1         0  0
# 6     4.0       217         1     -1         0  0
# 7     4.0       380         1     -1         0  0
# 8     4.0        50         1     -1         0  0
# 9     4.0        55         1     -1         0  0
# 10    4.0       222         1     -1         0  0
# 11    4.0       137         1     -1         0  0
# 12    4.0       517         1     -1         0  0
# 13    4.0        71         1     -1         0  0
# 14    4.0       174         1     -1         0  0
# 15    4.0       353         1     -1         0  0
# 16    4.0        98         1     -1         0  0
# 17    4.0        38         1     -1         0  0
# 18    4.0       219         1     -1         0  0
# 19    4.0        54         1     -1         0  0
# 20    4.0       262         1     -1         0  0
# 21    4.0       164         1     -1         0  0
# 22    4.0       160         1     -1         0  0
# 23    4.0       342         1     -1         0  0
# 24    4.0       181         1     -1         0  0
# 25    4.0       172         1     -1         0  0
# 26    4.0       296         1     -1         0  0
# 27    4.0       127         1     -1         0  0
# 28    4.0       255         2     -1         0  0
# 29    4.0       348         1     -1         0  0
# 30    4.0       225         1     -1         0  0
# 31    4.0       230         1     -1         0  0
# 32    4.0       208         1     -1         0  0
# 33    4.0       226         1     -1         0  0
# 34    4.0       336         1     -1         0  0
# 35    4.0       242         1     -1         0  0
# 36    4.0       365         1     -1         0  0
# 37    4.0      1666         1     -1         0  0
# 38    4.0       577         1     -1         0  0
# 39    4.0       137         1     -1         0  0
# 40    4.0       160         1     -1         0  0
# 41    4.0       180         2     -1         0  0
# 42    4.0        22         1     -1         0  0
# 43    4.0      1492         1     -1         0  0
# 44    4.0       616         1     -1         0  0
# 45    4.0       242         1     -1         0  0
# 46    4.0       355         1     -1         0  0
# 47    4.0       225         2     -1         0  0
# 48    4.0       160         1     -1         0  0
# 49    4.0       363         1     -1         0  0

# %%
market_df.isnull().sum()
# Out:
# age              0
# job           5171
# marital          0
# education        0
# default          0
# housing          0
# loan             0
# contact          0
# day              0
# month        13142
# duration         0
# campaign         0
# pdays            0
# previous         0
# y                0
# dtype: int64

# %% [markdown]
# market_df.dopna()

# %%
market_df=market_df.dropna(axis=1)

# %%
market_df.isnull().sum()
# Out:
# age          0
# marital      0
# education    0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# duration     0
# campaign     0
# pdays        0
# previous     0
# y            0
# dtype: int64

# %%
feature=market_df.drop(['y'],axis=1)

# %%
target=market_df.iloc[:,-1:]

# %%
X_train,X_test,y_train,y_test=train_test_split(feature,target,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#        age  marital  education  default  housing  loan  contact  day  \
# 10747   36        1          3        0        0     0        1   17
# 26054   56        0          2        0        0     0        0   19
# 9125    46        0          2        0        1     0        1    5
# 41659   41        2          3        0        0     0        0    1
# 4443    38        0          2        0        1     0        1   20
#
#        duration  campaign  pdays  previous
# 10747       153         4     -1         0
# 26054       312         3     -1         0
# 9125         83         2     -1         0
# 41659       302         1    119         5
# 4443         90         1     -1         0

# %%
y_train.head()
# Out:
#        y
# 10747  0
# 26054  0
# 9125   0
# 41659  0
# 4443   0

# %% [markdown]
# # Logistic Regression

# %%
lr_model=LogisticRegression()

# %%
lr_model.fit(X_train,y_train)
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_model.score(X_train,y_train)
# Out:
# 0.8897525831832401

# %% [markdown]
# ## Random_Forest_Classifier

# %%
rfc_model=RandomForestClassifier()

# %%
rfc_model.fit(X_train,y_train)
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
rfc_model.score(X_train,y_train)*100
# Out:
# 99.99684014282555

# %%
round(rfc_model.score(X_test,y_test)*100)
# Out:
# 89

# %%
from joblib import dump

# %%
dump(rfc_model,"./../savemodels/marketcampaign.joblib")
# Out:
# ['./../savemodels/marketcampaign.joblib']
